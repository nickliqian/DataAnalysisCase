# %%
import pandas as pd
import os

pd.options.display.max_columns = None

# %%
path = "/Users/nick/Documents/dataset/企业失信大赛/复赛/失信企业预测-update20200320"
train = pd.read_csv(os.path.join(path, "train_stage2_update_20200320.csv"))

# %%
train.shape
# Out:
# (14366, 664)

# %%
train.head()
# Out:
#    ID  企业类型    经营期限至  登记机关  企业状态    邮政编码       投资总额       注册资本     核准日期  \
# 0   1   9.0      NaN   1.0   0.0  266300  19.110000  19.110000  00:00.0
# 1   3  11.0      NaN   5.0   0.0  266000  29.154194  19.210446  00:00.0
# 2   9   0.0      NaN   3.0   0.0  266000        NaN  19.120045  13:31.0
# 3  10   0.0  42:05.0   9.0   0.0  266000        NaN  19.160223  00:00.0
# 4  14   0.0      NaN   2.0   0.0  266400        NaN  19.210446  00:00.0
#
#      行业代码 注销时间    经营期限自     成立日期  行业门类  企业类别  管辖机关  \
# 0  5154.0  NaN  00:00.0  00:00.0   1.0   0.0   1.0
# 1  7214.0  NaN  31:40.0  31:40.0   0.0   2.0   3.0
# 2  2110.0  NaN  13:31.0  13:31.0   2.0   0.0   4.0
# 3  5163.0  NaN  42:05.0  42:05.0   1.0   0.0   8.0
# 4  5439.0  NaN  55:27.0  55:27.0   4.0   0.0   2.0
#
#                                                 经营范围         增值税      企业所得税  \
# 0  [1412, 1024, 21375, 15023, 18526, 18789, 17022...  106.039650   0.331552
# ...
